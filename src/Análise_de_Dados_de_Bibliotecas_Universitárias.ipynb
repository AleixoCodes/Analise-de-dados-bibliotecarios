# %% [markdown]
# <a href="https://colab.research.google.com/github/AleixoCodes/Analise-de-dados-bibliotecarios/blob/main/An%C3%A1lise_de_Dados_de_Bibliotecas_Universit%C3%A1rias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Extração e manipulação de dados de empréstimos dos acervos do sistema de bibliotecas da UFRN**

# %% [markdown]
# ## **Importando Dados**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
emprestimos2010_1 = pd.read_csv('C:\\Users\\aleix\\Documents\\Materiais de estudos\\Free_Programing\\Análise de Dados de Biblioteca Universitária\\Analise-de-dados-bibliotecarios\\emprestimos\\emprestimos-20101.csv')
emprestimos2010_2 = pd.read_csv('C:\\Users\\aleix\\Documents\\Materiais de estudos\\Free_Programing\\Análise de Dados de Biblioteca Universitária\\Analise-de-dados-bibliotecarios\\emprestimos\\emprestimos-20102.csv')
emprestimos2011_1 = pd.read_csv('C:\\Users\\aleix\\Documents\\Materiais de estudos\\Free_Programing\\Análise de Dados de Biblioteca Universitária\\Analise-de-dados-bibliotecarios\\emprestimos\\emprestimos-20111.csv')
emprestimos2011_2 = pd.read_csv('C:\\Users\\aleix\\Documents\\Materiais de estudos\\Free_Programing\\Análise de Dados de Biblioteca Universitária\\Analise-de-dados-bibliotecarios\\emprestimos\\emprestimos-20112.csv')
emprestimos2012_1 = pd.read_csv('C:\\Users\\aleix\\Documents\\Materiais de estudos\\Free_Programing\\Análise de Dados de Biblioteca Universitária\\Analise-de-dados-bibliotecarios\\emprestimos\\emprestimos-20121.csv')
emprestimos2012_2 = pd.read_csv('C:\\Users\\aleix\\Documents\\Materiais de estudos\\Free_Programing\\Análise de Dados de Biblioteca Universitária\\Analise-de-dados-bibliotecarios\\emprestimos\\emprestimos-20122.csv')
emprestimos2013_1 = pd.read_csv('C:\\Users\\aleix\\Documents\\Materiais de estudos\\Free_Programing\\Análise de Dados de Biblioteca Universitária\\Analise-de-dados-bibliotecarios\\emprestimos\\emprestimos-20131.csv')
emprestimos2013_2 = pd.read_csv('C:\\Users\\aleix\\Documents\\Materiais de estudos\\Free_Programing\\Análise de Dados de Biblioteca Universitária\\Analise-de-dados-bibliotecarios\\emprestimos\\emprestimos-20132.csv')
emprestimos2014_1 = pd.read_csv('C:\\Users\\aleix\\Documents\\Materiais de estudos\\Free_Programing\\Análise de Dados de Biblioteca Universitária\\Analise-de-dados-bibliotecarios\\emprestimos\\emprestimos-20141.csv')
emprestimos2014_2 = pd.read_csv('C:\\Users\\aleix\\Documents\\Materiais de estudos\\Free_Programing\\Análise de Dados de Biblioteca Universitária\\Analise-de-dados-bibliotecarios\\emprestimos\\emprestimos-20142.csv')
emprestimos2015_1 = pd.read_csv('C:\\Users\\aleix\\Documents\\Materiais de estudos\\Free_Programing\\Análise de Dados de Biblioteca Universitária\\Analise-de-dados-bibliotecarios\\emprestimos\\emprestimos-20151.csv')
emprestimos2015_2 = pd.read_csv('C:\\Users\\aleix\\Documents\\Materiais de estudos\\Free_Programing\\Análise de Dados de Biblioteca Universitária\\Analise-de-dados-bibliotecarios\\emprestimos\\emprestimos-20152.csv')
emprestimos2016_1 = pd.read_csv('C:\\Users\\aleix\\Documents\\Materiais de estudos\\Free_Programing\\Análise de Dados de Biblioteca Universitária\\Analise-de-dados-bibliotecarios\\emprestimos\\emprestimos-20161.csv')
emprestimos2016_2 = pd.read_csv('C:\\Users\\aleix\\Documents\\Materiais de estudos\\Free_Programing\\Análise de Dados de Biblioteca Universitária\\Analise-de-dados-bibliotecarios\\emprestimos\\emprestimos-20162.csv')
emprestimos2017_1 = pd.read_csv('C:\\Users\\aleix\\Documents\\Materiais de estudos\\Free_Programing\\Análise de Dados de Biblioteca Universitária\\Analise-de-dados-bibliotecarios\\emprestimos\\emprestimos-20171.csv')
emprestimos2017_2 = pd.read_csv('C:\\Users\\aleix\\Documents\\Materiais de estudos\\Free_Programing\\Análise de Dados de Biblioteca Universitária\\Analise-de-dados-bibliotecarios\\emprestimos\\emprestimos-20172.csv')
emprestimos2018_1 = pd.read_csv('C:\\Users\\aleix\\Documents\\Materiais de estudos\\Free_Programing\\Análise de Dados de Biblioteca Universitária\\Analise-de-dados-bibliotecarios\\emprestimos\\emprestimos-20181.csv')
emprestimos2018_2 = pd.read_csv('C:\\Users\\aleix\\Documents\\Materiais de estudos\\Free_Programing\\Análise de Dados de Biblioteca Universitária\\Analise-de-dados-bibliotecarios\\emprestimos\\emprestimos-20182.csv')
emprestimos2019_1 = pd.read_csv('C:\\Users\\aleix\\Documents\\Materiais de estudos\\Free_Programing\\Análise de Dados de Biblioteca Universitária\\Analise-de-dados-bibliotecarios\\emprestimos\\emprestimos-20191.csv')
emprestimos2019_2 = pd.read_csv('C:\\Users\\aleix\\Documents\\Materiais de estudos\\Free_Programing\\Análise de Dados de Biblioteca Universitária\\Analise-de-dados-bibliotecarios\\emprestimos\\emprestimos-20192.csv')
emprestimos2020_1 = pd.read_csv('C:\\Users\\aleix\\Documents\\Materiais de estudos\\Free_Programing\\Análise de Dados de Biblioteca Universitária\\Analise-de-dados-bibliotecarios\\emprestimos\\emprestimos-20201.csv')

# %% [markdown]
# ## **Concatenando DataFrames**

# %%
BibliotecaDeEmprestimos = pd.concat([emprestimos2010_1, emprestimos2010_2, emprestimos2011_1, emprestimos2011_2,
                          emprestimos2012_1, emprestimos2012_2, emprestimos2013_1, emprestimos2013_2,
                          emprestimos2014_1, emprestimos2014_2, emprestimos2015_1, emprestimos2015_2,
                          emprestimos2016_1, emprestimos2016_2, emprestimos2017_1, emprestimos2017_2,
                          emprestimos2018_1, emprestimos2018_2, emprestimos2019_1, emprestimos2019_2,
                          emprestimos2020_1], ignore_index=True)
BibliotecaDeEmprestimos
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709684       L095049                            NaN
# ...                ...           ...                            ...
# 2258013        2989086    2008047044                            NaN
# 2258014        2989087    2008047047                            NaN
# 2258015        2989088    2010052905                            NaN
# 2258016        2989089    2010048023                            NaN
# 2258017        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %% [markdown]
# ## **Filtrando as duplicatas**

# %%
BibliotecaDeEmprestimos = BibliotecaDeEmprestimos.drop_duplicates()
BibliotecaDeEmprestimos.value_counts()
BibliotecaDeEmprestimos
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 8               709688    2007027500  2010/01/19 15:59:26.464000000
# ...                ...           ...                            ...
# 2258013        2989086    2008047044                            NaN
# 2258014        2989087    2008047047                            NaN
# 2258015        2989088    2010052905                            NaN
# 2258016        2989089    2010048023                            NaN
# 2258017        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %% [markdown]
# ## **Importando Dados Exemplares**

# %%
DadosExemplares = pd.read_parquet('C:\\Users\\aleix\\Documents\\Materiais de estudos\\Free_Programing\\Análise de Dados de Biblioteca Universitária\\Analise-de-dados-bibliotecarios\\emprestimos\\dados_exemplares.parquet')
DadosExemplares
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# ...

# %% [markdown]
# ##**Mesclando Dados**

# %%
DadosCompletos = BibliotecaDeEmprestimos.merge(DadosExemplares)
DadosCompletos
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709688    2007027500  2010/01/19 15:59:26.464000000
# ...                ...           ...                            ...
# 2072517        2989086    2008047044                            NaN
# 2072518        2989087    2008047047                            NaN
# 2072519        2989088    2010052905                            NaN
# 2072520        2989089    2010048023                            NaN
# 2072521        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %% [markdown]
# ## **Organizando os Dados corretamente**

# %% [markdown]
# Adicionando célula de CDU

# %%
lista_CDU = []

for CDU in DadosCompletos['localizacao']:
 if (CDU < 100):
  lista_CDU.append('Generalidades')
 elif (CDU < 200):
  lista_CDU.append('Filosofia e psicologia')
 elif (CDU < 300):
  lista_CDU.append('Religião')
 elif (CDU < 400):
  lista_CDU.append('Ciências sociais')
 elif (CDU< 500):
  lista_CDU.append('Classe vaga')
 elif (CDU < 600):
  lista_CDU.append('Matemática e ciências naturais')
 elif (CDU < 700):
  lista_CDU.append('Ciências aplicadas')
 elif (CDU < 800):
  lista_CDU.append('Belas artes')
 elif (CDU < 900):
  lista_CDU.append('Linguagens')
 else:
  lista_CDU.append('Geografia e historia')
DadosCompletos['CDU'] = lista_CDU
DadosCompletos
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709688    2007027500  2010/01/19 15:59:26.464000000
# ...                ...           ...                            ...
# 2072517        2989086    2008047044                            NaN
# 2072518        2989087    2008047047                            NaN
# 2072519        2989088    2010052905                            NaN
# 2072520        2989089    2010048023                            NaN
# 2072521        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %% [markdown]
# Modificando e Excluindo células desnecessárias

# %%
DadosCompletos.drop(columns=['registro_sistema'], inplace=True)

DadosCompletos['matricula_ou_siape'] = DadosCompletos['matricula_ou_siape'].astype(str)
DadosCompletos
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709688    2007027500  2010/01/19 15:59:26.464000000
# ...                ...           ...                            ...
# 2072517        2989086    2008047044                            NaN
# 2072518        2989087    2008047047                            NaN
# 2072519        2989088    2010052905                            NaN
# 2072520        2989089    2010048023                            NaN
# 2072521        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %% [markdown]
# ## **Explorando DateTimes da biblioteca**

# %% [markdown]
# Anlisando a relação entre empréstimos normais e exemplares

# %%
exemplar_counts = DadosCompletos.groupby('id_emprestimo')['id_exemplar'].nunique()

# Filtrando emprestimos com mais de um ID exemplar
maisdeumID = exemplar_counts[exemplar_counts > 1]
maisdeumID
# Out:
# id_emprestimo
# 711239      2
# 711444      2
# 711563      2
# 713133      2
# 717196      2
#            ..
# 10312580    2
# 10315036    2
# 10317144    2
# 10320136    2
# 10321388    2
# Name: id_exemplar, Length: 3786, dtype: int64

# %% [markdown]
# Nota-se que um único ID de empréstimo pode apresentar mais de um exemplar.
#
# Conluindo que cada linha é o empréstimo de cada exemplar.

# %% [markdown]
# Total de emprestimos

# %%
Total = len(DadosCompletos['id_emprestimo'].drop_duplicates())
print(f'Total de empréstimos foi {Total}')
# Out:
# Total de empréstimos foi 2068724

# %% [markdown]
# Total de emprestimos exemplares

# %%
exemplares = len(DadosCompletos['id_exemplar'])
print(f'Total de exemplares foi {exemplares}')
# Out:
# Total de exemplares foi 2072522

# %% [markdown]
# Livros exemplares emprestados por ano

# %%
dataEmprestimos = pd.DataFrame(DadosCompletos['data_emprestimo'].value_counts()).reset_index()
dataEmprestimos.columns = ['Data', 'Quantidade']
dataEmprestimos['Data'] = pd.to_datetime(dataEmprestimos['Data'])

# Organizando a quantidade dos emprestimos dos livros por ano
emprestimosPorAno = dataEmprestimos.groupby(dataEmprestimos['Data'].dt.year)['Quantidade'].sum().reset_index()
emprestimosPorAno
# Out:
#     Data  Quantidade
# 0   2010      161394
# 1   2011      196390
# 2   2012      221365
# 3   2013      234749
# 4   2014      219189
# 5   2015      213582
# 6   2016      215900
# 7   2017      218462
# 8   2018      194080
# 9   2019      171801
# 10  2020       25610

# %% [markdown]
# ## **Formulando gráfico para análise dos dados anuais**

# %%
plt.figure(figsize=(10, 6))
plt.plot(emprestimosPorAno['Data'], emprestimosPorAno['Quantidade'], marker='o')
plt.xlabel('Ano')
plt.ylabel('Quantidade')
plt.title('Quantidade de exemplares emprestados por ano')
plt.xticks(emprestimosPorAno['Data'], rotation=30)
plt.grid(True)
plt.show()

# %% [markdown]
# ### **Relatório da análise anual**
#
# Pode-se afirmar que a partir do ano de **2013** o número de empréstimos de livros feitos pela universidade decaiu, com ênfase no ano de **2019** que ocorreu uma queda considerável desses exemplares.
#
# Com isso, é necessária a **observação cuidadosa** por parte da biblioteca com relação ao sistema de empréstimos de livros **após 2013**, a fim de encontrar o motivo da diminuição desses empréstimos.

# %% [markdown]
# ## **Verificando empréstimos feitos por mês**

# %%
emprestimosPorMes = dataEmprestimos.groupby(dataEmprestimos['Data'].dt.month)['Quantidade'].sum().reset_index()

# trocando numeros por meses
meses = {1:'Jan', 2:'Fev', 3:'Mar', 4:'Abril', 5:'Maio', 6:'Jun', 7:'Jul', 8:'Ago', 9:'Set', 10:'Out', 11:'Nov', 12:'Dez'}
emprestimosPorMes['Data'] = emprestimosPorMes['Data'].map(meses)

emprestimosPorMes.columns = ['Mês', 'Quantidade']
emprestimosPorMes
# Out:
#       Mês  Quantidade
# 0     Jan       67514
# 1     Fev      210200
# 2     Mar      252185
# 3   Abril      208725
# 4    Maio      202530
# 5     Jun      138123
# 6     Jul      123790
# 7     Ago      232793
# 8     Set      208234
# 9     Out      188410
# 10    Nov      164222
# 11    Dez       75796

# %% [markdown]
# **Formulando gráfico para análise dos dados mensais**

# %%
plt.figure(figsize=(10, 6))
plt.plot(emprestimosPorMes['Mês'], emprestimosPorMes['Quantidade'], marker='o')
plt.ylabel('Quantidade')
plt.title('Quantidade de exemplares emprestados por mês (entre 2010 e 2020)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### **Relatório da análise dos dados mensais**
#
# Percebe-se que o ápice dos empréstimos foram nos meses de **Março** e **Agosto**. Além disso, foram constatadas grandes quedas nos períodos entre **Junho** - **Julho** e **Dezembro** - **Janeiro**, devido as férias no período letivo.
#
# Até o momento os dados não demonstram anormalidades, contudo, existem estratégias que a diretoria da biblioteca pode adotar para aumentar o número de empréstimos durante os meses de baixa, como a organização de eventos e atividades extracurriculares, ou ações de marketing para estimular a leitura durante as férias.

# %% [markdown]
# ## **Verificando empréstimos feitos por hora**

# %%
emprestimosPorHora = dataEmprestimos.groupby(dataEmprestimos['Data'].dt.hour)['Quantidade'].sum().reset_index()
emprestimosPorHora.columns = ['Hora', 'Quantidade']
emprestimosPorHora
# Out:
#     Hora  Quantidade
# 0      0          17
# 1      6          14
# 2      7       18777
# 3      8      103416
# 4      9      131273
# 5     10      185839
# 6     11      180048
# 7     12      148754
# 8     13      126987
# 9     14      150876
# 10    15      166672
# 11    16      210655
# 12    17      185340
# 13    18      182520
# 14    19      102129
# 15    20      127716
# 16    21       51191
# 17    22         247
# 18    23          51

# %% [markdown]
# **Formulando gráfico para análise dos dados por hora**

# %%
plt.figure(figsize=(10, 6))
bar = sns.barplot(data=emprestimosPorHora,y='Quantidade',x='Hora',
                 palette='Blues',hue='Quantidade',dodge=False)

plt.legend([],[], frameon=False)

bar.set(xlabel='Horário',ylabel='Quantidade')
bar.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))
bar.set_title("Quantidade de exemplares emprestados por faixa horária"+"\n",size=15,loc='left',weight='bold')
bar.text(s='Período de 2010 a 2020',x=-0.5,y=225000,fontsize=12, ha='left',color='gray')
bar=bar

# %% [markdown]
# ### **Relatório da análise dos dados por hora**
#
# Através do gráfico é possível identificar que os períodos entre às 10h e 16h são os de maior pico no atendimento de empréstimos.
#
# Além disso, os períodos do começo da manhã (entre 7h e 9) e da noite (entre 19h e 22) podem ser os melhores horários para que se realizem as demais atividades além do atendimento.

# %% [markdown]
# #### Modificando tipo dos dados de datas do DataFrame

# %%
DadosCompletos['data_emprestimo'] = pd.to_datetime(DadosCompletos['data_emprestimo'])
DadosCompletos['data_renovacao'] = pd.to_datetime(DadosCompletos['data_renovacao'])
DadosCompletos['data_devolucao'] = pd.to_datetime(DadosCompletos['data_devolucao'])

DadosCompletos.head(8)
# Out:
#    id_emprestimo codigo_barras          data_renovacao  \
# 0         709684       L095049                     NaT
# 1         709685       L167050                     NaT
# 2         709686    2006017618 2010-01-26 08:07:01.738
# 3         709687       L184117 2010-01-18 11:07:46.470
# 4         709688    2007027500 2010-01-19 15:59:26.464
# 5         709689       L157395 2010-01-19 15:59:26.447
# 6         709690    2007019312                     NaT
# 7         709691    2008046357 2010-01-19 11:50:13.404
#
#           data_emprestimo          data_devolucao matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662       2008023265.0
# 1 2010-01-04 07:44:10.750 2010-01-12 07:34:13.934       2008023265.0
# 2 2010-01-04 08:08:44.081 2010-02-25 07:36:25.800       2008112114.0
# 3 2010-01-04 08:24:21.284 2010-02-03 08:58:45.692        200721119.0
# 4 2010-01-04 08:27:33.569 2010-02-03 13:06:30.662       2009045971.0
# ...

# %% [markdown]
# ## **Verificando valores das variáveis**

# %%
DadosCompletos.tipo_vinculo_usuario.unique()
# Out:
# <ArrowStringArray>
# [             'ALUNO DE GRADUAÇÃO',          'ALUNO DE PÓS-GRADUAÇÃO',
#                          'DOCENTE', 'SERVIDOR TÉCNICO-ADMINISTRATIVO',
#                  'DOCENTE EXTERNO',             'ALUNO MÉDIO/TÉCNICO',
#                  'USUÁRIO EXTERNO',                          'OUTROS']
# Length: 8, dtype: str

# %%
DadosCompletos.biblioteca.unique()
# Out:
# <ArrowStringArray>
# [                                                          'Biblioteca Central Zila Mamede',
#  'Biblioteca Setorial Prof. Rodolfo Helinski - Escola Agrícola de Jundiaí - EAJ  - Macaiba',
#                'Biblioteca Setorial Bertha Cruz Enders - ­Escola de Saúde da UFRN - ESUFRN',
#                                     'Biblioteca Setorial do Centro Ciências da Saúde - CCS',
#           'Biblioteca Setorial Prof. Alberto Moreira Campos - ­Departamento de Odontologia',
#                                 'Biblioteca Setorial Prof. Ronaldo Xavier de Arruda - CCET',
#                 'Biblioteca Setorial do Centro de Ciências Humanas, Letras e Artes - CCHLA',
#         'Biblioteca Setorial Prof. Horácio Nicolas Solimo - ­ Engenharia Química - EQ - CT',
#            'Biblioteca Setorial Prof. Francisco Gurgel De Azevedo - Instituto Química - IQ',
#                           'Biblioteca Setorial do Centro Ciências Sociais Aplicadas - CCSA',
# ...

# %%
DadosCompletos.colecao.unique()
# Out:
# <ArrowStringArray>
# [                    'Acervo Circulante',
#                               'Folhetos',
#                                  'Teses',
#                           'Dissertações',
#                            'Monografias',
#           'Publicações de Autores do RN',
#                    'Publicações da UFRN',
#                             'Multimeios',
#                    'Coleção Mossoroense',
#                                'Eventos',
#                     'Trabalho Acadêmico',
#                    'Obras de Referência',
#                            'Obras Raras',
#                   'Literatura de Cordel',
#                    'Coleção Zila Mamede',
#  'Necessidades Educacionais Específicas']
# Length: 16, dtype: str

# %%
DadosCompletos.CDU.unique()
# Out:
# <ArrowStringArray>
# [            'Ciências aplicadas',                     'Linguagens',
#                'Ciências sociais',           'Geografia e historia',
#  'Matemática e ciências naturais',                       'Religião',
#                   'Generalidades',         'Filosofia e psicologia',
#                     'Belas artes']
# Length: 9, dtype: str

# %% [markdown]
# ###**Calculando a frequência das variáveis**

# %%
import plotly.express as px

# %%
def Valorfrequencia(variavel):

  frequencia = pd.DataFrame(DadosCompletos[variavel].value_counts())
  frequencia.columns = ['Quantidade']
  frequencia['Porcentagem'] = round(frequencia.Quantidade / frequencia.Quantidade.sum() * 100, 1)

  return frequencia

# %% [markdown]
# ### **Analisando as frequências de cada variável**

# %% [markdown]
# #### **Frequência dos tipos de vinculo por usuario**

# %%
Valorfrequencia('tipo_vinculo_usuario')
# Out:
#                                  Quantidade  Porcentagem
# tipo_vinculo_usuario
# ALUNO DE GRADUAÇÃO                  1612324         77.8
# ALUNO DE PÓS-GRADUAÇÃO               302541         14.6
# DOCENTE                               70981          3.4
# SERVIDOR TÉCNICO-ADMINISTRATIVO       32184          1.6
# ALUNO MÉDIO/TÉCNICO                   28029          1.4
# DOCENTE EXTERNO                       23949          1.2
# USUÁRIO EXTERNO                        2509          0.1
# OUTROS                                    5          0.0

# %%
frequencia_tipo_vinculo = Valorfrequencia('tipo_vinculo_usuario')

plt.figure(figsize=(12, 7))
bar = sns.barplot(data=frequencia_tipo_vinculo, y='Porcentagem', x=frequencia_tipo_vinculo.index, palette='crest', hue='Porcentagem', dodge=False)

plt.legend([], [], frameon=False)
plt.xlabel('Tipo de Vínculo do Usuário')
plt.ylabel('Porcentagem')
plt.title('Frequência de Empréstimos por Tipo de Vínculo de Usuário')
plt.xticks(rotation=45, ha='right')
bar.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### **Análise da frequência dos tipos de usuários**
# ---
# Percebe-se que o grande volume de empréstimos se deve aos alunos de graduação, responsáveis por, praticamente, 80% dos empréstimos totais. Em seguida, os alunos de pós-graduação representam o segundo maior público com cerca de 15% dos empréstimos totais.
#
# Possilvemente a maior diferença entre os percentuais dos dois públicos anteriores é devido a dois pontos:
#
# - Alunos de pós graduação, priorizam estudar por artigos científicos que são acessados através de bases de dados bibliográficas.
#
# - A grande diferença no número de alunos de graduação em comparação com os da pós na universidade.

# %% [markdown]
# #### **Frequência das coleções literárias**

# %%
Valorfrequencia('colecao')
# Out:
#                                        Quantidade  Porcentagem
# colecao
# Acervo Circulante                         2053120         99.1
# Multimeios                                   7954          0.4
# Monografias                                  4021          0.2
# Dissertações                                 2406          0.1
# Obras de Referência                          1954          0.1
# Publicações de Autores do RN                  866          0.0
# Publicações da UFRN                           764          0.0
# Teses                                         714          0.0
# Folhetos                                      271          0.0
# Necessidades Educacionais Específicas         130          0.0
# Trabalho Acadêmico                            115          0.0
# Eventos                                       101          0.0
# Coleção Mossoroense                            44          0.0
# Coleção Zila Mamede                            30          0.0
# ...

# %% [markdown]
# ##### **Análise da frequência das coleções**
# ---
# Percebe-se que a principal coleção é a própria **circulante** o que se cria um alerta, pois está com **99%** de todos os exemplares emprestados.
#
# Principalmente para as monografias, dissertações e teses que poderiam estar sendo mais consultadas para que haja um crescimento das discussões de pesquisa interna da instituição.
#
# Entretanto é importante verificar se esses documentos não estão disponíveis na coleção online e por este motivo não é emprestada fisicamente.
#
# As coleções: Coleção Mossoroense, Coleção Zila Mamede, Literatura de Cordel, Obras Raras devem ter uma atenção especial em entender a razão que estão com números tão pequenos de frequências.

# %% [markdown]
# #### **Frequência das variáveis bibliotecas**

# %%
Valorfrequencia('biblioteca')
# Out:
#                                                     Quantidade  Porcentagem
# biblioteca
# Biblioteca Central Zila Mamede                         1426122         68.8
# Biblioteca Setorial do Centro Ciências da Saúde...      118614          5.7
# Biblioteca Setorial da Faculdade de Ciências da...       77609          3.7
# Biblioteca Setorial Prof. Alberto Moreira Campo...       66447          3.2
# Biblioteca Setorial Profª. Maria Lúcia da Costa...       61478          3.0
# Biblioteca Setorial Bertha Cruz Enders - ­Escol...       46040          2.2
# Biblioteca Setorial do Centro de Ciências Human...       40744          2.0
# Biblioteca Setorial Dr. Paulo Bezerra - EMCM/RN...       32097          1.5
# Biblioteca Setorial Profª. Maria José Mamede Ga...       29089          1.4
# Biblioteca Setorial Prof. Rodolfo Helinski - Es...       27219          1.3
# Biblioteca Setorial Prof. Francisco Gurgel De A...       26923          1.3
# ...

# %% [markdown]
# ##### **Análise da Frequência das bibliotecas**
# ---
# De acordo com a tabela de frequência, cerca de 70% do empréstimos foram executados na biblioteca **Central Zila Mamede**.
#
# Este ranking é importante para se entender o contexto geral do sistema de bibliotecas, entretanto para que se enriqueça ainda mais essa análise se faz necessário uma avaliação interna de outras métricas, como:
#
# - A quantidade esperada de empréstimos.
# - Quantidade de empréstimos por usuário cadastrado em cada biblioteca.
# - Ações e investimentos realizados em cada uma.

# %% [markdown]
# #### **Frequência dos tipos de CDU**

# %%
Valorfrequencia('CDU')
# Out:
#                                 Quantidade  Porcentagem
# CDU
# Ciências aplicadas                 1425473         68.8
# Ciências sociais                    369536         17.8
# Matemática e ciências naturais       68744          3.3
# Generalidades                        62521          3.0
# Religião                             62295          3.0
# Filosofia e psicologia               60563          2.9
# Geografia e historia                  7989          0.4
# Belas artes                           7911          0.4
# Linguagens                            7490          0.4

# %%
Frquencia_CDU = Valorfrequencia('CDU')

plt.figure(figsize=(12, 7))
plt.bar(Frquencia_CDU.index, Frquencia_CDU['Porcentagem'])
plt.xlabel('Classificação Decimal Universal')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Porcentagem')
plt.title('Frequência de Empréstimos por CDU')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### **Análise da frequência dos tipos de CDU**
# ---
# Assim como as variáveis anteriores, nota-se uma grande diferença de uma das matérias com relação as outras.
#
# A matéria **Ciência Aplicadas** foi a mais procurada, praticamente 70% dos empréstimos efeutados pelos estudantes eram relacionados a este tema.
# Além disso, será importante entender a razão de materiais do tema de Geografia/História, Belas artes e Linguagem estão com números tão baixos.
#
# Fica os possíveis questionamentos:
#
# - O acervo está atualizado?
# - O público da biblioteca tem a necessidade destas informações? Se sim, por que não estão usando?
# - Quais ações de marketing estão sendo realizadas para esses temas?

# %% [markdown]
# ## **Visualização em Boxplot dos Alunos de Graduação e de Pós**

# %% [markdown]
# ### **Alunos de Graduação**

# %%
alunosGraduacao = DadosCompletos.query('tipo_vinculo_usuario == "ALUNO DE GRADUAÇÃO"')
alunosGraduacao.colecao.value_counts().reset_index()
# Out:
#                                   colecao    count
# 0                       Acervo Circulante  1600155
# 1                              Multimeios     4652
# 2                             Monografias     3572
# 3                            Dissertações     1152
# 4                     Obras de Referência     1047
# 5            Publicações de Autores do RN      595
# 6                     Publicações da UFRN      466
# 7                                   Teses      245
# 8                                Folhetos      180
# 9                      Trabalho Acadêmico       81
# 10  Necessidades Educacionais Específicas       73
# 11                                Eventos       57
# 12                    Coleção Mossoroense       17
# 13                    Coleção Zila Mamede       15
# 14                   Literatura de Cordel       11
# 15                            Obras Raras        6

# %% [markdown]
# ### **Criando gráfico com quantidade mensal por ano**

# %%
import plotly.express as px

alunosGraduacao = alunosGraduacao.copy()
alunosGraduacao['ano_emprestimo'] = alunosGraduacao['data_emprestimo'].dt.year
alunosGraduacao['mes_emprestimo'] = alunosGraduacao['data_emprestimo'].dt.month

emprestimos_graduacao_mensal_anual = alunosGraduacao.groupby(['ano_emprestimo', 'mes_emprestimo']).size().reset_index(name='quantidade_emprestimos')

boxplot = px.box(emprestimos_graduacao_mensal_anual.sort_values('ano_emprestimo'), x='ano_emprestimo', y='quantidade_emprestimos')
boxplot = boxplot.update_layout(xaxis_title='Ano', yaxis_title='Quantidade de Empréstimos', title='Distribuição dos empréstimos mensais(alunos de graduação)'+'\n', xaxis = dict(tickmode = 'array', tickvals = emprestimos_graduacao_mensal_anual['ano_emprestimo'].unique()))
boxplot.show()

# %% [markdown]
# #### **Relatório da distribuição dos empréstimos mensais**
# ---
# Com o boxplot é possível observar a oscilação da quantidade de empréstimos realizados mensalmente durante cada ano.
#
# Além da análise geral realizada - **declínio a partir de 2013, forte baixa em 2019** - chama atenção os anos de **2014 e 2017**. Que se excluíssemos os outliers (possivelmente meses de janeiro e dezembro) teríamos anos com uma quantidade constante de empréstimos mensais.
#
# Mas se diferenciam principalmente porque em 2014 houve um declínio e em 2017 houve um aumento, em relação aos anos anteriores. Seria interessante entender com a direção das bibliotecas o que ocorreu nessas datas para que pudéssemos ter um contexto melhor da realidade do negócio.

# %% [markdown]
# ### **Alunos de Pós-Graduação**

# %%
alunosPos = DadosCompletos.query('tipo_vinculo_usuario == "ALUNO DE PÓS-GRADUAÇÃO"')
alunosPos.colecao.value_counts().reset_index()
# Out:
#                                   colecao   count
# 0                       Acervo Circulante  299201
# 1                            Dissertações     934
# 2                     Obras de Referência     700
# 3                              Multimeios     559
# 4                                   Teses     367
# 5                             Monografias     278
# 6            Publicações de Autores do RN     204
# 7                     Publicações da UFRN     121
# 8                                Folhetos      60
# 9   Necessidades Educacionais Específicas      30
# 10                                Eventos      26
# 11                    Coleção Mossoroense      23
# 12                     Trabalho Acadêmico      23
# 13                    Coleção Zila Mamede      11
# 14                   Literatura de Cordel       4

# %% [markdown]
# ### **Criando gráfico com quantidade mensal por ano**

# %%
alunosPos = alunosPos.copy()

alunosPos['ano_emprestimo'] = alunosPos['data_emprestimo'].dt.year
alunosPos['mes_emprestimo'] = alunosPos['data_emprestimo'].dt.month

emprestimos_Pos_mensal_anual = alunosPos.groupby(['ano_emprestimo', 'mes_emprestimo']).size().reset_index(name='quantidade_emprestimos')

plotbox = px.box(emprestimos_Pos_mensal_anual.sort_values('ano_emprestimo'), x='ano_emprestimo', y='quantidade_emprestimos')
plotbox = plotbox.update_layout(xaxis_title='Ano', yaxis_title='Quantidade de Empréstimos', title='Distribuição dos empréstimos mensais(alunos de pós graduação)', xaxis = dict(tickmode = 'array', tickvals = emprestimos_Pos_mensal_anual['ano_emprestimo'].unique()))
plotbox.show()

# %% [markdown]
# #### **Relatório da distribuição dos empréstimos mensais**
# ---
# Percebe-se que os alunos de pós graduação tiveram um comportamento diferente em relação ao declínio a partir de 2013.
#
# Nos dois gráficos observa-se um grande aumento entre **2010 e 2013**, levantando o questionamento de quais procedimentos estavam sendo realizados neste período para que houvesse esse crescimento.
#
# Nos dois recortes visualiza-se que a partir de **2018** tivemos um forte declínio e é um alerta para que a direção possa entender o que está ocorrendo.

# %%
arq_json = pd.read_json('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/refs/heads/main/Dia_6-Novos_dados_novas_analises/Datasets/cadastro_alunos.json')
arq_json.head()
# Out:
#      tipo_curso                                          registros
# 0     GRADUACAO  [{"matricula_ou_siape": "2009029003.0", "tipo_...
# 1  POSGRADUACAO  [{"matricula_ou_siape": "2008112114.0", "tipo_...
